# %%
import seaborn as sns
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
print (sns.get_dataset_names())
# Out:
# ['anagrams', 'anscombe', 'attention', 'brain_networks', 'car_crashes', 'diamonds', 'dots', 'dowjones', 'exercise', 'flights', 'fmri', 'geyser', 'glue', 'healthexp', 'iris', 'mpg', 'penguins', 'planets', 'seaice', 'taxis', 'tips', 'titanic', 'anagrams', 'anagrams', 'anscombe', 'anscombe', 'attention', 'attention', 'brain_networks', 'brain_networks', 'car_crashes', 'car_crashes', 'diamonds', 'diamonds', 'dots', 'dots', 'dowjones', 'dowjones', 'exercise', 'exercise', 'flights', 'flights', 'fmri', 'fmri', 'geyser', 'geyser', 'glue', 'glue', 'healthexp', 'healthexp', 'iris', 'iris', 'mpg', 'mpg', 'penguins', 'penguins', 'planets', 'planets', 'seaice', 'seaice', 'taxis', 'taxis', 'tips', 'tips', 'titanic', 'titanic', 'anagrams', 'anscombe', 'attention', 'brain_networks', 'car_crashes', 'diamonds', 'dots', 'dowjones', 'exercise', 'flights', 'fmri', 'geyser', 'glue', 'healthexp', 'iris', 'mpg', 'penguins', 'planets', 'seaice', 'taxis', 'tips', 'titanic']

# %%
data = pd.read_excel("Cardiac_Outcomes.xlsx",
sheet_name=['Hospitalization_Discharge','CardiacComplications','Responsivenes','PatientHistory','Labs','Demography','Patient_Precriptions'])

# %%
sheet5_df=data['Labs']
#locate the sheet
wbc=sheet5_df.loc[:,['white_blood_cell']]
print(wbc)
# Out:
#       white_blood_cell
# 0                 9.43
# 1                 5.32
# 2                13.01
# 3                 2.18
# 4                 6.14
# ...                ...
# 2003              4.04
# 2004              4.58
# 2005              5.39
# 2006              9.70
# 2007              5.34
#
# [2008 rows x 1 columns]

# %%
#33	Retrieve the row with minimum white_blood_cell count using sorting technique.
sheet5_df=data['Labs']
#locate the sheet
wbc=sheet5_df.loc[:,['white_blood_cell']].min()
print(wbc)
print("Minimum: ",wbc["white_blood_cell"].min())
# Out:
# white_blood_cell    1.66
# dtype: float64
# Minimum:  1.66

# %%
#34	get the last letter of discharge_department of patients using RegEX
import re
sheet1_df=data['Hospitalization_Discharge']
dd=sheet1_df.loc[:,['discharge_department']]
for index, row in dd.iterrows():
    lastletter = row[0]
    lastletter = lastletter[len(lastletter)-1]
    print(lastletter)
# Out:
# y
# y
# y
# y
# y
# y
# y
# y
# y
# y
# y
# y
# y
# y
# y
# y
# y
# y
# y
# s
# y
# y
# d
# y
# y
# y
# y
# d
# y
# y
# y
# y
# y
# y
# y
# d
# y
# y
# y
# y
# d
# y
# y
# U
# y
# y
# y
# y
# y
# y
# y
# y
# y
# d
# y
# d
# y
# y
# y
# y
# y
# y
# y
# y
# s
# s
# y
# y
# y
# y
# y
# y
# y
# y
# y
# y
# y
# y
# y
# y
# y
# y
# y
# d
# y
# y
# d
# y
# y
# U
# y
# y
# y
# y
# y
# y
# y
# y
# d
# d
# y
# y
# y
# d
# y
# y
# y
# y
# s
# y
# y
# y
# y
# y
# y
# y
# y
# d
# y
# y
# y
# d
# y
# d
# y
# y
# y
# y
# d
# y
# y
# y
# y
# y
# y
# y
# y
# y
# y
# y
# U
# y
# y
# y
# y
# y
# y
# U
# y
# y
# y
# y
# y
# y
# y
# y
# y
# y
# y
# y
# d
# y
# y
# y
# y
# y
# y
# y
# d
# y
# y
# y
# d
# y
# y
# y
# y
# y
# y
# y
# y
# y
# y
# y
# y
# d
# y
# y
# y
# y
# d
# y
# d
# y
# y
# y
# y
# y
# y
# y
# d
# y
# y
# y
# y
# y
# y
# y
# y
# y
# y
# y
# y
# s
# y
# y
# y
# y
# y
# y
# y
# y
# d
# y
# d
# y
# y
# y
# y
# y
# y
# y
# y
# y
# d
# d
# d
# y
# y
# y
# y
# y
# y
# y
# y
# y
# d
# y
# y
# y
# ...

# %%
sheet1_df=data['Hospitalization_Discharge']
dd=sheet1_df.loc[:,['discharge_department']]
print(dd)
# Out:
#      discharge_department
# 0              Cardiology
# 1              Cardiology
# 2              Cardiology
# 3              Cardiology
# 4              Cardiology
# ...                   ...
# 2003          GeneralWard
# 2004          GeneralWard
# 2005           Cardiology
# 2006           Cardiology
# 2007           Cardiology
#
# [2008 rows x 1 columns]

# %%
#35	find the way to reverse string for given input (eg: input : This hackathon is about cardiac outcomes: outcomes cardiac about is hackathon This)
sheet7_df=data['Patient_Precriptions']
cc=sheet7_df.loc[:,['Drug_name']]
cardio=[cc[::-1]]
print(cardio)
# Out:
# [                                              Drug_name
# 15369  Meglumine Adenosine Cyclophosphate for injection
# 15368                              Furosemide injection
# 15367                               Milrinone injection
# 15366                             Deslanoside injection
# 15365                              Furosemide injection
# ...                                                 ...
# 4                                  Furosemide injection
# 3      Meglumine Adenosine Cyclophosphate for injection
# 2                           Enoxaparin Sodium injection
# 1                                     Furosemide tablet
# 0                      sulfotanshinone sodium injection
#
# [15370 rows x 1 columns]]

# %%
#36	"Use the QB style library to create any multidimensional arrays.Create a figure object called fig using plt.figure() **
#** Use add_axes to add an axis to the figure canvas at [0,0,1,1]. Call this new axis ax. **
#** Plot (x,y) on that axes and set the labels.

# %%
sheet7_df=data['Patient_Precriptions']
cc=sheet7_df.loc[:,['Drug_name']]
def reverse(cc):
    
    str = ""
    
    for i in cc:
        str = i + str
    return str
  
print("The reversed string(using loops) is : ", str)
print(reverse(cc))
# Out:
# The reversed string(using loops) is :
# Drug_name

# %%
pip install qbstyles
# Out:
# ...
#
# ...

# %%
from qbstyles import mpl_style

# %%
mpl_style(dark=True)

# %%
#36	"Use the QB style library to create any multidimensional arrays.Create a figure object called fig using plt.figure() **
#** Use add_axes to add an axis to the figure canvas at [0,0,1,1]. Call this new axis ax. **
#** Plot (x,y) on that axes and set the labels.
import matplotlib.pyplot as plt
from qbstyles import mpl_style

fig,ax = plt.subplots()
ax.plot([0,0,1,1],[2,1,3,1])
#sheet7_df=data['Patient_Precriptions']
#cc=sheet7_df.loc[:,['Drug_name']]

# %%
#37	Using dischargeDay values print even if it even number and odd if it odd number
sheet1_df=data['Hospitalization_Discharge']
disd=sheet1_df.loc[:,['dischargeDay']]
num=int(input(disd))
print("Even numbers are=")
      
          
Even_or_Odd(num)
# Out:
#   Cell In[326], line 12
#     elif
#     ^
# SyntaxError: invalid syntax

# %%
#38	find the length of Tuple for any given input (Hint: Input a string from user )
